# %% [markdown]
# #Firstly, Importing necessary libraries

# %%
import pandas as pd #data manipulation and analysis
import pandas as pd # for data manipulation and analysis
import numpy as np # for numerical,computing and statistical computation of the data
import matplotlib.pyplot as plt #for data visualization
# %matplotlib inline
import seaborn as sns #making visualization colorful
import scipy.stats as stats #statistical computation factors
from scipy.stats import f_oneway

# %% [markdown]
# #Loading the data

# %%
df =pd.read_csv("/content/Epi_Task_Data.csv")

# %%
df
# Out:
#      year  epi_week    county age_group  ili_percentage  population
# 0    2023         1   Nairobi    0-4yrs             6.1        3452
# 1    2024         1   Nairobi    0-4yrs             3.2        3658
# 2    2023         2   Nairobi    0-4yrs             4.5        3043
# 3    2024         2   Nairobi    0-4yrs             4.9        2765
# 4    2023         3   Nairobi    0-4yrs             4.6        6975
# ..    ...       ...       ...       ...             ...         ...
# 275  2024         3  Kakamega    >50yrs             6.0        3554
# 276  2023         4  Kakamega    >50yrs             4.7        3300
# 277  2024         4  Kakamega    >50yrs             2.1        9860
# 278  2023         5  Kakamega    >50yrs             6.1        7747
# 279  2024         5  Kakamega    >50yrs             5.8        3411
#
# [280 rows x 6 columns]

# %% [markdown]
# #DATA OVERVIEW AND CLEANING

# %%
#alows you to see the top 10
df.head(10)
# Out:
#    year  epi_week   county age_group  ili_percentage  population
# 0  2023         1  Nairobi    0-4yrs             6.1        3452
# 1  2024         1  Nairobi    0-4yrs             3.2        3658
# 2  2023         2  Nairobi    0-4yrs             4.5        3043
# 3  2024         2  Nairobi    0-4yrs             4.9        2765
# 4  2023         3  Nairobi    0-4yrs             4.6        6975
# 5  2024         3  Nairobi    0-4yrs             3.8         609
# 6  2023         4  Nairobi    0-4yrs             6.3        1642
# 7  2024         4  Nairobi    0-4yrs             3.9        1118
# 8  2023         5  Nairobi    0-4yrs             7.0        9418
# 9  2024         5  Nairobi    0-4yrs             3.9         526

# %%
#allows you to see the bottom 10 just to check if there is consistency in the inputed data
df.tail(10)
# Out:
#      year  epi_week    county age_group  ili_percentage  population
# 270  2023         1  Kakamega    >50yrs             4.9        3083
# 271  2024         1  Kakamega    >50yrs             4.1        6386
# 272  2023         2  Kakamega    >50yrs             4.2        4405
# 273  2024         2  Kakamega    >50yrs             4.6        8983
# 274  2023         3  Kakamega    >50yrs             3.4        8615
# 275  2024         3  Kakamega    >50yrs             6.0        3554
# 276  2023         4  Kakamega    >50yrs             4.7        3300
# 277  2024         4  Kakamega    >50yrs             2.1        9860
# 278  2023         5  Kakamega    >50yrs             6.1        7747
# 279  2024         5  Kakamega    >50yrs             5.8        3411

# %%
#checking the data we are dealing with in terms of rows and colums
df.shape
# Out:
# (280, 6)

# %% [markdown]
# there are 280 rows and 6 columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 280 entries, 0 to 279
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   year            280 non-null    int64
#  1   epi_week        280 non-null    int64
#  2   county          280 non-null    object
#  3   age_group       280 non-null    object
#  4   ili_percentage  280 non-null    float64
#  5   population      280 non-null    int64
# dtypes: float64(1), int64(3), object(2)
# memory usage: 13.3+ KB

# %%
#viewing measures of central tendancy including all columns in the output even those withnull values
df.describe(include = "all")
# Out:
#                year    epi_week   county age_group  ili_percentage  \
# count    280.000000  280.000000      280       280      280.000000
# unique          NaN         NaN        7         4             NaN
# top             NaN         NaN  Nairobi    0-4yrs             NaN
# freq            NaN         NaN       40        70             NaN
# mean    2023.500000    3.000000      NaN       NaN        3.981786
# std        0.500895    1.416746      NaN       NaN        1.446237
# min     2023.000000    1.000000      NaN       NaN        0.500000
# 25%     2023.000000    2.000000      NaN       NaN        3.000000
# 50%     2023.500000    3.000000      NaN       NaN        4.000000
# 75%     2024.000000    4.000000      NaN       NaN        5.000000
# max     2024.000000    5.000000      NaN       NaN        8.100000
#
#          population
# count    280.000000
# unique          NaN
# top             NaN
# freq            NaN
# mean    5281.875000
# std     2761.336872
# min      526.000000
# 25%     3015.500000
# 50%     5110.500000
# 75%     7790.250000
# max     9992.000000

# %%
#  #checking for the number of non-uniques values within the data in each column
df.nunique()
# Out:
# year                2
# epi_week            5
# county              7
# age_group           4
# ili_percentage     62
# population        274
# dtype: int64

# %%
#checking for null values within the dataset
df.isna()
# Out:
#       year  epi_week  county  age_group  ili_percentage  population
# 0    False     False   False      False           False       False
# 1    False     False   False      False           False       False
# 2    False     False   False      False           False       False
# 3    False     False   False      False           False       False
# 4    False     False   False      False           False       False
# ..     ...       ...     ...        ...             ...         ...
# 275  False     False   False      False           False       False
# 276  False     False   False      False           False       False
# 277  False     False   False      False           False       False
# 278  False     False   False      False           False       False
# 279  False     False   False      False           False       False
#
# [280 rows x 6 columns]

# %%
df.isna().sum()
# Out:
# year              0
# epi_week          0
# county            0
# age_group         0
# ili_percentage    0
# population        0
# dtype: int64

# %% [markdown]
# #Computing a table showing mean ILI% per county per year

# %%
df.columns
# Out:
# Index(['year', 'epi_week', 'county', 'age_group', 'ili_percentage',
#        'population'],
#       dtype='object')

# %%
#grouping the counties by year with their ili percentages in each county
#This shows the ili percentage per county per year
df.groupby (['year', 'county'])['ili_percentage'].mean()
# Out:
# year  county
# 2023  Kakamega    4.060
#       Kiambu      3.895
#       Kisumu      4.065
#       Machakos    3.380
#       Mombasa     3.895
#       Nairobi     4.220
#       Nakuru      3.780
# 2024  Kakamega    4.540
#       Kiambu      3.705
#       Kisumu      3.725
#       Machakos    3.975
#       Mombasa     3.985
#       Nairobi     3.990
#       Nakuru      4.530
# Name: ili_percentage, dtype: float64

# %% [markdown]
# WEEKLY ILI TRENDS ACROSS THE DIFFERENT COUNTIES

# %%
df1=df[['county','epi_week', 'ili_percentage']]

# %%
#this shows a table(dataframe) the grouped data of the epi week trends across each county
df1
# Out:
#        county  epi_week  ili_percentage
# 0     Nairobi         1             6.1
# 1     Nairobi         1             3.2
# 2     Nairobi         2             4.5
# 3     Nairobi         2             4.9
# 4     Nairobi         3             4.6
# ..        ...       ...             ...
# 275  Kakamega         3             6.0
# 276  Kakamega         4             4.7
# 277  Kakamega         4             2.1
# 278  Kakamega         5             6.1
# 279  Kakamega         5             5.8
#
# [280 rows x 3 columns]

# %%
sns.boxplot(data =df1, x ='county', y='ili_percentage', hue='epi_week', palette='Set3')
plt.title('Weekly ILI Trends Across Counties')
plt.xlabel('County')
plt.ylabel('ILI Percentage')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# Calculate the incidence rates per 100,000 population across any three counties

# %%
df.columns
# Out:
# Index(['year', 'epi_week', 'county', 'age_group', 'ili_percentage',
#        'population'],
#       dtype='object')

# %%
df_1=df[df['county']=='Nairobi']

# %%
df_1
# Out:
#      year  epi_week   county age_group  ili_percentage  population
# 0    2023         1  Nairobi    0-4yrs             6.1        3452
# 1    2024         1  Nairobi    0-4yrs             3.2        3658
# 2    2023         2  Nairobi    0-4yrs             4.5        3043
# 3    2024         2  Nairobi    0-4yrs             4.9        2765
# 4    2023         3  Nairobi    0-4yrs             4.6        6975
# 5    2024         3  Nairobi    0-4yrs             3.8         609
# 6    2023         4  Nairobi    0-4yrs             6.3        1642
# 7    2024         4  Nairobi    0-4yrs             3.9        1118
# 8    2023         5  Nairobi    0-4yrs             7.0        9418
# 9    2024         5  Nairobi    0-4yrs             3.9         526
# 70   2023         1  Nairobi   5-14yrs             2.4        7611
# 71   2024         1  Nairobi   5-14yrs             3.9        8557
# 72   2023         2  Nairobi   5-14yrs             4.9        8786
# 73   2024         2  Nairobi   5-14yrs             2.6        6552
# 74   2023         3  Nairobi   5-14yrs             3.2        3530
# 75   2024         3  Nairobi   5-14yrs             4.9        2780
# 76   2023         4  Nairobi   5-14yrs             5.2        1517
# 77   2024         4  Nairobi   5-14yrs             4.7         830
# 78   2023         5  Nairobi   5-14yrs             2.7        1684
# 79   2024         5  Nairobi   5-14yrs             2.4        3639
# 140  2023         1  Nairobi  15-49yrs             3.9        5767
# 141  2024         1  Nairobi  15-49yrs             2.7        2342
# 142  2023         2  Nairobi  15-49yrs             3.3        3221
# 143  2024         2  Nairobi  15-49yrs             4.0        9992
# 144  2023         3  Nairobi  15-49yrs             3.4        8871
# 145  2024         3  Nairobi  15-49yrs             5.7        3570
# 146  2023         4  Nairobi  15-49yrs             3.3        3654
# 147  2024         4  Nairobi  15-49yrs             3.4        1246
# 148  2023         5  Nairobi  15-49yrs             5.0        4165
# 149  2024         5  Nairobi  15-49yrs             2.4        1437
# 210  2023         1  Nairobi    >50yrs             2.2        8140
# 211  2024         1  Nairobi    >50yrs             7.1        2039
# 212  2023         2  Nairobi    >50yrs             4.2        6543
# 213  2024         2  Nairobi    >50yrs             3.9        1564
# 214  2023         3  Nairobi    >50yrs             4.7        5972
# 215  2024         3  Nairobi    >50yrs             4.1        3257
# 216  2023         4  Nairobi    >50yrs             3.8        1409
# 217  2024         4  Nairobi    >50yrs             6.2        5244
# 218  2023         5  Nairobi    >50yrs             3.7        6735
# 219  2024         5  Nairobi    >50yrs             2.1         914

# %%
df_1[['population', 'ili_percentage']]
# Out:
#      population  ili_percentage
# 0          3452             6.1
# 1          3658             3.2
# 2          3043             4.5
# 3          2765             4.9
# 4          6975             4.6
# 5           609             3.8
# 6          1642             6.3
# 7          1118             3.9
# 8          9418             7.0
# 9           526             3.9
# 70         7611             2.4
# 71         8557             3.9
# 72         8786             4.9
# 73         6552             2.6
# 74         3530             3.2
# 75         2780             4.9
# 76         1517             5.2
# 77          830             4.7
# 78         1684             2.7
# 79         3639             2.4
# 140        5767             3.9
# 141        2342             2.7
# 142        3221             3.3
# 143        9992             4.0
# 144        8871             3.4
# 145        3570             5.7
# 146        3654             3.3
# 147        1246             3.4
# 148        4165             5.0
# 149        1437             2.4
# 210        8140             2.2
# 211        2039             7.1
# 212        6543             4.2
# 213        1564             3.9
# 214        5972             4.7
# 215        3257             4.1
# 216        1409             3.8
# 217        5244             6.2
# 218        6735             3.7
# 219         914             2.1

# %%
df_1[['population']].sum()
# Out:
# population    164774
# dtype: int64

# %%
df_1['ili_percentage'].mean()
# Out:
# np.float64(4.1049999999999995)

# %%
df_1_population_group= df_1[['population']].sum()/100000
df_1_population_group
# Out:
# population    1.64774
# dtype: float64

# %%
incidence_rate_1=df_1_population_group * (df_1['ili_percentage'].mean())
incidence_rate_1
# Out:
# population    6.763973
# dtype: float64

# %% [markdown]
# Comparing ili percentages across three counties

# %%
df['county'].value_counts()
# Out:
# county
# Nairobi     40
# Mombasa     40
# Kisumu      40
# Nakuru      40
# Machakos    40
# Kiambu      40
# Kakamega    40
# Name: count, dtype: int64

# %%
counties =['Nairobi', 'Mombasa', 'Nakuru']
df_filtered =df[df['county'].isin(counties)]
df_filtered
# Out:
#      year  epi_week   county age_group  ili_percentage  population
# 0    2023         1  Nairobi    0-4yrs             6.1        3452
# 1    2024         1  Nairobi    0-4yrs             3.2        3658
# 2    2023         2  Nairobi    0-4yrs             4.5        3043
# 3    2024         2  Nairobi    0-4yrs             4.9        2765
# 4    2023         3  Nairobi    0-4yrs             4.6        6975
# ..    ...       ...      ...       ...             ...         ...
# 245  2024         3   Nakuru    >50yrs             7.1        1765
# 246  2023         4   Nakuru    >50yrs             5.5        9180
# 247  2024         4   Nakuru    >50yrs             4.0         534
# 248  2023         5   Nakuru    >50yrs             5.1        6902
# 249  2024         5   Nakuru    >50yrs             2.5        4796
#
# [120 rows x 6 columns]

# %%
#incidence=(number of ili cases/population)*100000
#getting number of ili cases = ili_perecentage*population
estimated_ili_cases=(df_filtered['ili_percentage']/100)*df_filtered['population']
estimated_ili_cases
# Out:
# 0      210.572
# 1      117.056
# 2      136.935
# 3      135.485
# 4      320.850
#         ...
# 245    125.315
# 246    504.900
# 247     21.360
# 248    352.002
# 249    119.900
# Length: 120, dtype: float64

# %%
df_filtered['estimated_ili_cases'] = estimated_ili_cases
estimated_ili_cases
# Out:
# <ipython-input-45-dca1f042e722>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['estimated_ili_cases'] = estimated_ili_cases
# 0      210.572
# 1      117.056
# 2      136.935
# 3      135.485
# 4      320.850
#         ...
# 245    125.315
# 246    504.900
# 247     21.360
# 248    352.002
# 249    119.900
# Length: 120, dtype: float64

# %%
#grouping by county and year, them summing cases and population
summary=df_filtered.groupby(['county','year']).agg({'estimated_ili_cases':'sum','population':'sum'}).reset_index()
summary
# Out:
#     county  year  estimated_ili_cases  population
# 0  Mombasa  2023             5214.200      127104
# 1  Mombasa  2024             3769.399       96170
# 2  Nairobi  2023             4280.512      102135
# 3  Nairobi  2024             2533.320       62639
# 4   Nakuru  2023             4874.614      128862
# 5   Nakuru  2024             4386.045       96021

# %%
#calculating incidence per 100,000
summary['incidence_per_100k']= (summary['estimated_ili_cases']/summary['population'])*100000
summary[['county', 'year', 'incidence_per_100k']]
# Out:
#     county  year  incidence_per_100k
# 0  Mombasa  2023         4102.309919
# 1  Mombasa  2024         3919.516481
# 2  Nairobi  2023         4191.033436
# 3  Nairobi  2024         4044.317438
# 4   Nakuru  2023         3782.817277
# 5   Nakuru  2024         4567.797669

# %%
sns.lineplot(data=summary, x='year', y='incidence_per_100k', hue='county', marker='o')
plt.title('ILI Incidence Rates per 100k population Across selected Counties Over Time')
plt.xlabel('Year')
plt.ylabel('Incidence per 100,000')
plt.legend(title='County')
plt.grid(True)
plt.tight_layout
plt.show()

# %%
#seperate ili_percentage for each county
#first choose county
counties_2=['Machakos', 'Kisumu', 'Kakamega']
df_filtered_2 =df[df['county'].isin(counties_2)]
df_filtered_2
# Out:
#      year  epi_week    county age_group  ili_percentage  population
# 20   2023         1    Kisumu    0-4yrs             3.5        3908
# 21   2024         1    Kisumu    0-4yrs             1.3        2647
# 22   2023         2    Kisumu    0-4yrs             3.7        2233
# 23   2024         2    Kisumu    0-4yrs             5.8        4029
# 24   2023         3    Kisumu    0-4yrs             6.8        1519
# ..    ...       ...       ...       ...             ...         ...
# 275  2024         3  Kakamega    >50yrs             6.0        3554
# 276  2023         4  Kakamega    >50yrs             4.7        3300
# 277  2024         4  Kakamega    >50yrs             2.1        9860
# 278  2023         5  Kakamega    >50yrs             6.1        7747
# 279  2024         5  Kakamega    >50yrs             5.8        3411
#
# [120 rows x 6 columns]

# %%
#seperating the ili perecentages for the 3 counties
machakos_ili =df_filtered_2[df_filtered_2['county'] =='Machakos']['ili_percentage']
kisumu_ili =df_filtered_2[df_filtered_2['county'] =='Kisumu']['ili_percentage']
kakamega_ili =df_filtered_2[df_filtered_2['county'] =='Kakamega']['ili_percentage']

# %%
machakos_ili
kisumu_ili
kakamega_ili
# Out:
# 60     3.4
# 61     4.3
# 62     4.9
# 63     6.1
# 64     2.9
# 65     6.0
# 66     4.5
# 67     5.6
# 68     5.4
# 69     5.1
# 130    4.9
# 131    3.3
# 132    4.0
# 133    5.7
# 134    6.2
# 135    2.4
# 136    3.8
# 137    5.8
# 138    3.3
# 139    3.9
# 200    1.0
# 201    4.5
# 202    5.8
# 203    7.1
# 204    1.9
# 205    2.3
# 206    2.9
# 207    2.4
# 208    3.0
# 209    3.7
# 270    4.9
# 271    4.1
# 272    4.2
# 273    4.6
# 274    3.4
# 275    6.0
# 276    4.7
# 277    2.1
# 278    6.1
# 279    5.8
# Name: ili_percentage, dtype: float64

# %%
#perform one-way Anova
f_statistic, p_value = f_oneway(machakos_ili, kisumu_ili, kakamega_ili)

# %%
#results of the one way Anova
print("F-statistic:", f_statistic)
print("P-value:", p_value)
# Out:
# F-statistic: 2.0577814979817277
# P-value: 0.1323352988754866

# %%
if p_value < 0.05:
    print("There is a significant difference in ili percentages between the three counties.")
else:
    print("There is no significant difference in ili percentages between the three counties.")
# Out:
# There is no significant difference in ili percentages between the three counties.

# %%
#visualizing the differences in ili percentages between the three counties
sns.boxplot(data=df_filtered_2, x='county', y='ili_percentage', palette='Set2')
plt.title('Comparison of ILI Percentages Across Three Counties')
plt.xlabel('County')
plt.ylabel('ILI Percentage')
plt.grid(True, axis='y')
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-52-ede7bbb6939d>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df_filtered_2, x='county', y='ili_percentage', palette='Set2')
